# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"C:\Users\Lenovo\Desktop\image.jpeg")

# %%
image = cv2.imread(r"C:\Users\Lenovo\Desktop\image.jpeg")

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)

# %%
plt.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.show()
